# %% [markdown]
# Doubts of the previous topics.

# %%
# WAP to check if the input number is a Buzz number or not.

num = int(input("Enter a number: "))

if (num % 7 == 0) or (num % 10 == 7):
    print(num, "is a Buzz number.")
else:
    print(num, "is NOT a Buzz number.")
# Out:
# 34 is NOT a Buzz number.
