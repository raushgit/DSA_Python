# %% [markdown]
# Topic : Break and Continue Statement

# %%
'''
Finding the GCD & LCM
'''
import math

a = 48
b = 18

gcd_val = math.gcd(a, b)
lcm_val = math.lcm(a, b)

print(f"GCD: ",gcd_val)
print(f"LCM: ",lcm_val)
# Out:
# GCD:  6
# LCM:  144
