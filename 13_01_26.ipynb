# %% [markdown]
# Topics: Datatypes in Python, Case Sensitivity and Indentation. How to take Input and Output

# %%
#WAP to input 2 numbers and print their sum.

num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))

result = num1 + num2

print(result)
# Out:
# The sum is: 3

# %%
#WAP to calculate the area and perimeter of the rectangle.

length = float(input("Enter the length of the rectangle: "))
width = float(input("Enter the width of the rectangle: "))

area = length * width

perimeter = 2 * (length + width)

print("The Area is: ",area)
print("The Perimeter is: ",perimeter)
# Out:
# The Area is:  144.0
# The Perimeter is:  48.0
